# %% [markdown]
# <a href="https://colab.research.google.com/github/Arham-15/traffic-prediction-system/blob/dev/02_data_cleaning_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

print("IntelliTraffic Data Exploration ")
# Out:
# IntelliTraffic Data Exploration

# %%
import os
print(os.listdir("/content"))
# Out:
# ['.config', 'traffic-prediction-system', 'sample_data']

# %%
import pandas as pd

# %%
import pandas as pd

file_path = "/content/traffic-prediction-system/Metro_Interstate_Traffic_Volume.csv.gz"

df = pd.read_csv(file_path)
print("Dataset loaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4189/9450075.py in <cell line: 0>()
#       3 file_path = "/content/traffic-prediction-system/Metro_Interstate_Traffic_Volume.csv.gz"
#       4
# ----> 5 df = pd.read_csv(file_path)
#       6 print("Dataset loaded successfully!")
#
# ...

# %%
import os

data_dir = "/content/traffic-prediction-system/data/external/"
print(f"Listing files in {data_dir}:")
for file in os.listdir(data_dir):
    print(file)
# Out:
# Listing files in /content/traffic-prediction-system/data/external/:
# .gitkeep

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2760/275371285.py in <cell line: 0>()
# ----> 1 print("Rows:", df.shape[0])
#       2 print("Columns:", df.shape[1])
#
# NameError: name 'df' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df.head()

# %%
df.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2760/281403043.py in <cell line: 0>()
# ----> 1 df.tail()
#
# NameError: name 'df' is not defined

# %%
df.columns

# %%
print(df.duplicated().sum())

# %%
print(df['date_time'].min())

print(df['date_time'].max())

# %%
print(df['date_time'].nunique())
len(df)

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2760/3771845804.py in <cell line: 0>()
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df['weather_description'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2760/2619164781.py in <cell line: 0>()
# ----> 1 df['weather_description'].value_counts()
#
# NameError: name 'df' is not defined

# %%
df['weather_main'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2760/1145356700.py in <cell line: 0>()
# ----> 1 df['weather_main'].value_counts()
#
# NameError: name 'df' is not defined

# %%
df['holiday'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2760/3942079315.py in <cell line: 0>()
# ----> 1 df['holiday'].value_counts()
#
# NameError: name 'df' is not defined

# %%
df["date_time"] = pd.to_datetime(df["date_time"])
df["year"] = df["date_time"].dt.year
df["month"] = df["date_time"].dt.month
df["day"] = df["date_time"].dt.day
df["hour"] = df["date_time"].dt.hour

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2760/3627053830.py in <cell line: 0>()
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %%
df.isnull().sum()

# %%
(df.isna().sum() / len(df)) * 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2760/1964958775.py in <cell line: 0>()
# ----> 1 (df.isna().sum() / len(df)) * 100
#
# NameError: name 'df' is not defined

# %%
df['date_time'].duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2760/774830130.py in <cell line: 0>()
# ----> 1 df['date_time'].duplicated().sum()
#
# NameError: name 'df' is not defined

# %%
df['date_time'].value_counts().head(10)

# %%
duplicate_time = df['date_time'].value_counts().index[0]
df[df['date_time'] == duplicate_time]

# %%
df[['date_time', 'year', 'month', 'day', 'hour']].head(10)

# %%
hourly_traffic = df.groupby('hour')['traffic_volume'].mean()
hourly_traffic
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2760/554509514.py in <cell line: 0>()
# ----> 1 hourly_traffic = df.groupby('hour')['traffic_volume'].mean()
#       2 hourly_traffic
#
# NameError: name 'df' is not defined

# %%
print(hourly_traffic.idxmax())
print(hourly_traffic.idxmin())

# %%
day_traffic = df.groupby('day')['traffic_volume'].mean()
day_traffic

# %%
df['day_of_week'] = df['date_time'].dt.day_name()
df[['date_time', 'day_of_week']].head(10)

# %%
day_traffic = df.groupby('day_of_week')['traffic_volume'].mean()
day_traffic
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2760/1540188969.py in <cell line: 0>()
# ----> 1 day_traffic = df.groupby('day_of_week')['traffic_volume'].mean()
#       2 day_traffic
#
# NameError: name 'df' is not defined

# %%
day_traffic.idxmax()

# %%
day_traffic.idxmin()

# %%
day_order = [
    'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'
]
df['day_of_week'] = pd.Categorical(df['day_of_week'], categories=day_order, ordered=True)

# %%
day_traffic = df.groupby('day_of_week', observed=True)['traffic_volume'].mean()
day_traffic

# %%
df['is_weekend'] = df['day_of_week'].isin(['Saturday', 'Sunday'])
df[['day_of_week', 'is_weekend']].head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2760/1154279704.py in <cell line: 0>()
# ----> 1 df['is_weekend'] = df['day_of_week'].isin(['Saturday', 'Sunday'])
#       2 df[['day_of_week', 'is_weekend']].head(10)
#
# NameError: name 'df' is not defined

# %%
weekend_traffic = df.groupby('is_weekend', observed=True)['traffic_volume'].mean()
weekend_traffic

# %%
import matplotlib.pyplot as plt

weekend_traffic.plot(kind='bar')

plt.title('Average traffic: Weekdays vs Weekend')
plt.xlabel('Weekend')
plt.ylabel('Average traffic')
plt.xticks([0, 1], ['Weekdays', 'Weekend'], rotation=0)
plt.show()

# %%
monthly_traffic = df.groupby('month')['traffic_volume'].mean()
monthly_traffic
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2760/269779606.py in <cell line: 0>()
# ----> 1 monthly_traffic = df.groupby('month')['traffic_volume'].mean()
#       2 monthly_traffic
#
# NameError: name 'df' is not defined

# %%
monthly_traffic.idxmax()

# %%
weather_traffic = df.groupby('weather_main')['traffic_volume'].mean().sort_values(ascending=False)
weather_traffic

# %%
df['weather_main'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2760/1145356700.py in <cell line: 0>()
# ----> 1 df['weather_main'].value_counts()
#
# NameError: name 'df' is not defined

# %%
holiday_traffic = df.groupby('holiday', dropna=False)['traffic_volume'].mean()
holiday_traffic.sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2760/2180804160.py in <cell line: 0>()
# ----> 1 holiday_traffic = df.groupby('holiday', dropna=False)['traffic_volume'].mean()
#       2 holiday_traffic.sort_values(ascending=False)
#
# NameError: name 'df' is not defined

# %%
df[['temp', 'traffic_volume']].corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2760/1019691794.py in <cell line: 0>()
# ----> 1 df[['temp', 'traffic_volume']].corr()
#
# NameError: name 'df' is not defined

# %%
df[['rain_1h', 'snow_1h', 'clouds_all', 'traffic_volume']].corr()

# %%
df['traffic_volume'].describe()

# %%
(df['traffic_volume']==0).sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2760/3456252759.py in <cell line: 0>()
# ----> 1 (df['traffic_volume']==0).sum()
#
# NameError: name 'df' is not defined

# %%
df[df['traffic_volume'] == 0]
