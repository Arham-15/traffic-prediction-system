# %% [markdown]
# <a href="https://colab.research.google.com/github/Arham-15/traffic-prediction-system/blob/dev/notebooks/02_data_cleaning_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

print("IntelliTraffic Data Exploration ")
# Out:
# IntelliTraffic Data Exploration

# %%
import pandas as pd

file_path = "/Metro_Interstate_Traffic_Volume_Cleaned-1.csv"

df = pd.read_csv(file_path)
print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 48187
# Columns: 14

# %%
df.head()
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0     NaN  288.28      0.0      0.0          40       Clouds
# 1     NaN  289.36      0.0      0.0          75       Clouds
# 2     NaN  289.58      0.0      0.0          90       Clouds
# 3     NaN  290.13      0.0      0.0          90       Clouds
# 4     NaN  291.14      0.0      0.0          75       Clouds
#
#   weather_description            date_time  traffic_volume  hour  day_of_week  \
# 0    scattered clouds  2012-10-02 09:00:00            5545     9            1
# 1       broken clouds  2012-10-02 10:00:00            4516    10            1
# 2     overcast clouds  2012-10-02 11:00:00            4767    11            1
# 3     overcast clouds  2012-10-02 12:00:00            5026    12            1
# 4       broken clouds  2012-10-02 13:00:00            4918    13            1
#
#    month  year  is_weekend
# 0     10  2012           0
# 1     10  2012           0
# 2     10  2012           0
# 3     10  2012           0
# 4     10  2012           0

# %%
df.tail()
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 48182     NaN  283.45      0.0      0.0          75        Clouds
# 48183     NaN  282.76      0.0      0.0          90        Clouds
# 48184     NaN  282.73      0.0      0.0          90  Thunderstorm
# 48185     NaN  282.09      0.0      0.0          90        Clouds
# 48186     NaN  282.12      0.0      0.0          90        Clouds
#
#           weather_description            date_time  traffic_volume  hour  \
# 48182           broken clouds  2018-09-30 19:00:00            3543    19
# 48183         overcast clouds  2018-09-30 20:00:00            2781    20
# 48184  proximity thunderstorm  2018-09-30 21:00:00            2159    21
# 48185         overcast clouds  2018-09-30 22:00:00            1450    22
# 48186         overcast clouds  2018-09-30 23:00:00             954    23
#
#        day_of_week  month  year  is_weekend
# 48182            6      9  2018           1
# 48183            6      9  2018           1
# 48184            6      9  2018           1
# 48185            6      9  2018           1
# 48186            6      9  2018           1

# %%
df.columns
# Out:
# Index(['holiday', 'temp', 'rain_1h', 'snow_1h', 'clouds_all', 'weather_main',
#        'weather_description', 'date_time', 'traffic_volume', 'hour',
#        'day_of_week', 'month', 'year', 'is_weekend'],
#       dtype='object')

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df['date_time'].min())

print(df['date_time'].max())
# Out:
# 2012-10-02 09:00:00
# 2018-09-30 23:00:00

# %%
print(df['date_time'].nunique())
len(df)
# Out:
# 40575
# 48187

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48187 entries, 0 to 48186
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   holiday              61 non-null     object
#  1   temp                 48187 non-null  float64
#  2   rain_1h              48187 non-null  float64
#  3   snow_1h              48187 non-null  float64
#  4   clouds_all           48187 non-null  int64
#  5   weather_main         48187 non-null  object
#  6   weather_description  48187 non-null  object
#  7   date_time            48187 non-null  object
#  8   traffic_volume       48187 non-null  int64
#  9   hour                 48187 non-null  int64
#  10  day_of_week          48187 non-null  int64
#  11  month                48187 non-null  int64
#  12  year                 48187 non-null  int64
#  13  is_weekend           48187 non-null  int64
# dtypes: float64(3), int64(7), object(4)
# memory usage: 5.1+ MB

# %%
df['weather_description'].value_counts()
# Out:
# weather_description
# sky is clear                           13384
# mist                                    5949
# overcast clouds                         5079
# broken clouds                           4663
# scattered clouds                        3460
# light rain                              3372
# few clouds                              1956
# light snow                              1945
# moderate rain                           1664
# haze                                    1360
# light intensity drizzle                 1099
# fog                                      912
# proximity thunderstorm                   673
# drizzle                                  651
# heavy snow                               616
# heavy intensity rain                     467
# snow                                     293
# proximity shower rain                    136
# thunderstorm                             124
# heavy intensity drizzle                   64
# thunderstorm with heavy rain              63
# thunderstorm with light rain              54
# proximity thunderstorm with rain          52
# thunderstorm with rain                    37
# smoke                                     20
# very heavy rain                           18
# thunderstorm with light drizzle           15
# light intensity shower rain               13
# proximity thunderstorm with drizzle       13
# light shower snow                         11
# shower drizzle                             6
# light rain and snow                        6
# squalls                                    4
# sleet                                      3
# freezing rain                              2
# thunderstorm with drizzle                  2
# shower snow                                1
# Name: count, dtype: int64

# %%
df['weather_main'].value_counts()
# Out:
# weather_main
# Clouds          15158
# Clear           13384
# Mist             5949
# Rain             5672
# Snow             2875
# Drizzle          1820
# Haze             1360
# Thunderstorm     1033
# Fog               912
# Smoke              20
# Squall              4
# Name: count, dtype: int64

# %%
df['holiday'].value_counts()
# Out:
# holiday
# Labor Day                    7
# Christmas Day                6
# Thanksgiving Day             6
# Martin Luther King Jr Day    6
# New Years Day                6
# Veterans Day                 5
# Columbus Day                 5
# Memorial Day                 5
# Washingtons Birthday         5
# State Fair                   5
# Independence Day             5
# Name: count, dtype: int64

# %%
df["date_time"] = pd.to_datetime(df["date_time"])
df["year"] = df["date_time"].dt.year
df["month"] = df["date_time"].dt.month
df["day"] = df["date_time"].dt.day
df["hour"] = df["date_time"].dt.hour

# %%
df.describe()
# Out:
#                temp       rain_1h       snow_1h    clouds_all  \
# count  48187.000000  48187.000000  48187.000000  48187.000000
# mean     281.258052      0.130358      0.000222     49.365451
# min      243.390000      0.000000      0.000000      0.000000
# 25%      272.160000      0.000000      0.000000      1.000000
# 50%      282.450000      0.000000      0.000000     64.000000
# 75%      291.806000      0.000000      0.000000     90.000000
# max      310.070000     55.630000      0.510000    100.000000
# std       12.713922      1.003542      0.008169     39.015213
#
#                            date_time  traffic_volume          hour  \
# count                          48187    48187.000000  48187.000000
# mean   2016-01-05 06:49:48.133729024     3259.618134     11.397742
# min              2012-10-02 09:00:00        0.000000      0.000000
# 25%              2014-02-06 07:30:00     1192.500000      5.000000
# 50%              2016-06-10 21:00:00     3379.000000     11.000000
# 75%              2017-08-11 05:30:00     4933.000000     17.000000
# max              2018-09-30 23:00:00     7280.000000     23.000000
# std                              NaN     1986.954465      6.940373
#
#         day_of_week         month          year    is_weekend           day
# count  48187.000000  48187.000000  48187.000000  48187.000000  48187.000000
# mean       2.984913      6.505240   2015.512047      0.284309     15.736402
# min        0.000000      1.000000   2012.000000      0.000000      1.000000
# 25%        1.000000      4.000000   2014.000000      0.000000      8.000000
# 50%        3.000000      7.000000   2016.000000      0.000000     16.000000
# 75%        5.000000      9.000000   2017.000000      1.000000     23.000000
# max        6.000000     12.000000   2018.000000      1.000000     31.000000
# std        2.006041      3.400285      1.893393      0.451089      8.721687

# %%
df.isnull().sum()
# Out:
# holiday                48126
# temp                       0
# rain_1h                    0
# snow_1h                    0
# clouds_all                 0
# weather_main               0
# weather_description        0
# date_time                  0
# traffic_volume             0
# hour                       0
# day_of_week                0
# month                      0
# year                       0
# is_weekend                 0
# day                        0
# dtype: int64

# %%
(df.isna().sum() / len(df)) * 100
# Out:
# holiday                99.87341
# temp                    0.00000
# rain_1h                 0.00000
# snow_1h                 0.00000
# clouds_all              0.00000
# weather_main            0.00000
# weather_description     0.00000
# date_time               0.00000
# traffic_volume          0.00000
# hour                    0.00000
# day_of_week             0.00000
# month                   0.00000
# year                    0.00000
# is_weekend              0.00000
# day                     0.00000
# dtype: float64

# %%
df['date_time'].duplicated().sum()
# Out:
# np.int64(7612)

# %%
df['date_time'].value_counts().head(10)
# Out:
# date_time
# 2013-05-19 10:00:00    6
# 2013-04-18 22:00:00    6
# 2016-12-25 21:00:00    5
# 2012-12-16 19:00:00    5
# 2012-12-16 21:00:00    5
# 2013-12-16 10:00:00    5
# 2018-03-20 14:00:00    5
# 2012-11-11 04:00:00    5
# 2012-11-11 09:00:00    5
# 2013-04-18 23:00:00    5
# Name: count, dtype: int64

# %%
duplicate_time = df['date_time'].value_counts().index[0]
df[df['date_time'] == duplicate_time]
# Out:
#      holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 6162     NaN  287.15      0.0      0.0          90          Rain
# 6163     NaN  287.15      0.0      0.0          90  Thunderstorm
# 6164     NaN  287.15      0.0      0.0          90          Rain
# 6165     NaN  287.15      0.0      0.0          90          Mist
# 6166     NaN  287.15      0.0      0.0          90  Thunderstorm
# 6167     NaN  287.15      0.0      0.0          90  Thunderstorm
#
#                weather_description           date_time  traffic_volume  hour  \
# 6162                    light rain 2013-05-19 10:00:00            3591    10
# 6163  thunderstorm with heavy rain 2013-05-19 10:00:00            3591    10
# 6164                 moderate rain 2013-05-19 10:00:00            3591    10
# 6165                          mist 2013-05-19 10:00:00            3591    10
# 6166        proximity thunderstorm 2013-05-19 10:00:00            3591    10
# 6167  thunderstorm with light rain 2013-05-19 10:00:00            3591    10
#
#       day_of_week  month  year  is_weekend  day
# 6162            6      5  2013           1   19
# 6163            6      5  2013           1   19
# 6164            6      5  2013           1   19
# 6165            6      5  2013           1   19
# 6166            6      5  2013           1   19
# 6167            6      5  2013           1   19

# %%
df[['date_time', 'year', 'month', 'day', 'hour']].head(10)
# Out:
#             date_time  year  month  day  hour
# 0 2012-10-02 09:00:00  2012     10    2     9
# 1 2012-10-02 10:00:00  2012     10    2    10
# 2 2012-10-02 11:00:00  2012     10    2    11
# 3 2012-10-02 12:00:00  2012     10    2    12
# 4 2012-10-02 13:00:00  2012     10    2    13
# 5 2012-10-02 14:00:00  2012     10    2    14
# 6 2012-10-02 15:00:00  2012     10    2    15
# 7 2012-10-02 16:00:00  2012     10    2    16
# 8 2012-10-02 17:00:00  2012     10    2    17
# 9 2012-10-02 18:00:00  2012     10    2    18

# %%
hourly_traffic = df.groupby('hour')['traffic_volume'].mean()
hourly_traffic
# Out:
# hour
# 0      834.984774
# 1      516.339033
# 2      388.353640
# 3      371.090864
# 4      702.551889
# 5     2094.573437
# 6     4140.503594
# 7     4740.181337
# 8     4587.497115
# 9     4385.277502
# 10    4184.135838
# 11    4465.569231
# 12    4718.031730
# 13    4714.652836
# 14    4931.888776
# 15    5240.459907
# 16    5663.756539
# 17    5310.076048
# 18    4263.563792
# 19    3275.206438
# 20    2834.667509
# 21    2668.940464
# 22    2199.405717
# 23    1469.135294
# Name: traffic_volume, dtype: float64

# %%
print(hourly_traffic.idxmax())
print(hourly_traffic.idxmin())
# Out:
# 16
# 3

# %%
day_traffic = df.groupby('day')['traffic_volume'].mean()
day_traffic
# Out:
# day
# 1     3228.472954
# 2     3242.425853
# 3     3319.200508
# 4     3192.080595
# 5     3195.951235
# 6     3323.642731
# 7     3340.882015
# 8     3347.191026
# 9     3341.943420
# 10    3285.964241
# 11    3125.118001
# 12    3273.352532
# 13    3285.687834
# 14    3258.390319
# 15    3177.372050
# 16    3258.436386
# 17    3332.039925
# 18    3313.860736
# 19    3346.315636
# 20    3385.097885
# 21    3403.693837
# 22    3240.414908
# 23    3206.748589
# 24    3178.159653
# 25    3132.336585
# 26    3082.138162
# 27    3247.120316
# 28    3280.186090
# 29    3220.285398
# 30    3235.205755
# 31    3237.080220
# Name: traffic_volume, dtype: float64

# %%
df['day_of_week'] = df['date_time'].dt.day_name()
df[['date_time', 'day_of_week']].head(10)
# Out:
#             date_time day_of_week
# 0 2012-10-02 09:00:00     Tuesday
# 1 2012-10-02 10:00:00     Tuesday
# 2 2012-10-02 11:00:00     Tuesday
# 3 2012-10-02 12:00:00     Tuesday
# 4 2012-10-02 13:00:00     Tuesday
# 5 2012-10-02 14:00:00     Tuesday
# 6 2012-10-02 15:00:00     Tuesday
# 7 2012-10-02 16:00:00     Tuesday
# 8 2012-10-02 17:00:00     Tuesday
# 9 2012-10-02 18:00:00     Tuesday

# %%
day_traffic = df.groupby('day_of_week')['traffic_volume'].mean()
day_traffic
# Out:
# day_of_week
# Friday       3655.325622
# Monday       3309.795786
# Saturday     2773.485212
# Sunday       2369.094760
# Thursday     3637.929431
# Tuesday      3488.339714
# Wednesday    3582.568582
# Name: traffic_volume, dtype: float64

# %%
day_traffic.idxmax()
# Out:
# 'Friday'

# %%
day_traffic.idxmin()
# Out:
# 'Sunday'

# %%
day_order = [
    'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'
]
df['day_of_week'] = pd.Categorical(df['day_of_week'], categories=day_order, ordered=True)

# %%
day_traffic = df.groupby('day_of_week', observed=True)['traffic_volume'].mean()
day_traffic
# Out:
# day_of_week
# Monday       3309.795786
# Tuesday      3488.339714
# Wednesday    3582.568582
# Thursday     3637.929431
# Friday       3655.325622
# Saturday     2773.485212
# Sunday       2369.094760
# Name: traffic_volume, dtype: float64

# %%
df['is_weekend'] = df['day_of_week'].isin(['Saturday', 'Sunday'])
df[['day_of_week', 'is_weekend']].head(10)
# Out:
#   day_of_week  is_weekend
# 0     Tuesday       False
# 1     Tuesday       False
# 2     Tuesday       False
# 3     Tuesday       False
# 4     Tuesday       False
# 5     Tuesday       False
# 6     Tuesday       False
# 7     Tuesday       False
# 8     Tuesday       False
# 9     Tuesday       False

# %%
weekend_traffic = df.groupby('is_weekend', observed=True)['traffic_volume'].mean()
weekend_traffic
# Out:
# is_weekend
# False    3533.291791
# True     2570.699635
# Name: traffic_volume, dtype: float64

# %%
import matplotlib.pyplot as plt

weekend_traffic.plot(kind='bar')

plt.title('Average traffic: Weekdays vs Weekend')
plt.xlabel('Weekend')
plt.ylabel('Average traffic')
plt.xticks([0, 1], ['Weekdays', 'Weekend'], rotation=0)
plt.show()

# %%
monthly_traffic = df.groupby('month')['traffic_volume'].mean()
monthly_traffic
# Out:
# month
# 1     3051.081378
# 2     3197.945547
# 3     3308.388611
# 4     3304.372388
# 5     3366.319432
# 6     3416.693043
# 7     3205.481752
# 8     3394.241891
# 9     3301.930737
# 10    3390.317972
# 11    3168.970955
# 12    3024.304286
# Name: traffic_volume, dtype: float64

# %%
monthly_traffic.idxmax()
# Out:
# np.int32(6)

# %%
weather_traffic = df.groupby('weather_main')['traffic_volume'].mean().sort_values(ascending=False)
weather_traffic
# Out:
# weather_main
# Clouds          3617.989115
# Haze            3502.101471
# Rain            3317.905501
# Drizzle         3292.189560
# Smoke           3237.650000
# Clear           3055.614465
# Snow            3016.321391
# Thunderstorm    2999.431752
# Mist            2933.343923
# Fog             2703.720395
# Squall          2061.750000
# Name: traffic_volume, dtype: float64

# %%
df['weather_main'].value_counts()
# Out:
# weather_main
# Clouds          15158
# Clear           13384
# Mist             5949
# Rain             5672
# Snow             2875
# Drizzle          1820
# Haze             1360
# Thunderstorm     1033
# Fog               912
# Smoke              20
# Squall              4
# Name: count, dtype: int64

# %%
holiday_traffic = df.groupby('holiday', dropna=False)['traffic_volume'].mean()
holiday_traffic.sort_values(ascending=False)
# Out:
# holiday
# NaN                          3262.652766
# New Years Day                1356.000000
# Memorial Day                 1107.600000
# Independence Day             1076.000000
# Labor Day                    1013.142857
# Thanksgiving Day              933.500000
# Christmas Day                 827.500000
# Veterans Day                  691.400000
# Washingtons Birthday          635.200000
# State Fair                    634.800000
# Martin Luther King Jr Day     612.666667
# Columbus Day                  519.400000
# Name: traffic_volume, dtype: float64

# %%
df[['temp', 'traffic_volume']].corr()
# Out:
#                     temp  traffic_volume
# temp            1.000000        0.132482
# traffic_volume  0.132482        1.000000

# %%
df[['rain_1h', 'snow_1h', 'clouds_all', 'traffic_volume']].corr()
# Out:
#                  rain_1h   snow_1h  clouds_all  traffic_volume
# rain_1h         1.000000  0.001523    0.081508       -0.022345
# snow_1h         0.001523  1.000000    0.027934        0.000736
# clouds_all      0.081508  0.027934    1.000000        0.067138
# traffic_volume -0.022345  0.000736    0.067138        1.000000

# %%
df['traffic_volume'].describe()
# Out:
# count    48187.000000
# mean      3259.618134
# std       1986.954465
# min          0.000000
# 25%       1192.500000
# 50%       3379.000000
# 75%       4933.000000
# max       7280.000000
# Name: traffic_volume, dtype: float64

# %%
(df['traffic_volume']==0).sum()
# Out:
# np.int64(2)

# %%
df[df['traffic_volume'] == 0]
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 25184     NaN  296.68      0.0      0.0          40         Rain
# 25189     NaN  295.90      0.0      0.0          90         Haze
#
#       weather_description           date_time  traffic_volume  hour  \
# 25184          light rain 2016-07-23 18:00:00               0    18
# 25189                haze 2016-07-23 23:00:00               0    23
#
#       day_of_week  month  year  is_weekend  day
# 25184    Saturday      7  2016        True   23
# 25189    Saturday      7  2016        True   23
